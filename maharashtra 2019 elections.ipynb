# %%
import geopandas as gdp

# %%
# required imports

import xlrd
import random
import pandas as pd
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt

sns.set_style('whitegrid')

# %%
map_df= gdp.read_file('India_AC.shp')

# %%
map_df.plot()

# %%
mah=map_df.loc[map_df['ST_NAME']=='MAHARASHTRA']

# %%
mah.plot()

# %%
mah.shape
# Out:
# (302, 14)

# %%
mah.head()
# Out:
#       OBJECTID  ST_CODE      ST_NAME  DT_CODE    DIST_NAME  AC_NO  \
# 2645         1       27  MAHARASHTRA      1.0  NANDURBAR *      1
# 2646         1       27  MAHARASHTRA      1.0  NANDURBAR *      2
# 2647         7       27  MAHARASHTRA      7.0     AMRAVATI     41
# 2648         1       27  MAHARASHTRA      1.0  NANDURBAR *      3
# 2649         1       27  MAHARASHTRA      2.0        DHULE      9
#
#              AC_NAME  PC_NO         PC_NAME  PC_ID STATUS  Shape_Leng  \
# 2645  Akkalkuwa (ST)      1  NANDURBAR (ST)   2701   None    2.894388
# 2646    Shahada (ST)      1  NANDURBAR (ST)   2701   None    2.618610
# 2647    Melghat (ST)      7   AMRAVATI (SC)   2707   None    3.711428
# 2648  Nandurbar (ST)      1  NANDURBAR (ST)   2701   None    2.580283
# 2649    Shirpur (ST)      1  NANDURBAR (ST)   2701   None    1.728193
#
#       Shape_Area                                           geometry
# 2645    0.194806  POLYGON ((74.43880 22.02530, 74.44376 22.02279...
# ...

# %%
mah=mah.set_index('DIST_NAME')

# %%
results=pd.read_csv('convertcsv.csv')

# %%
results.head()
# Out:
#    # Assembly Constituency                    Candidate  \
# 0  1             Akkalkuwa            Adv. K. C. Padavi
# 1  2               Shahada         Rajesh Udesing Padvi
# 2  3             Nandurbar  Vijaykumar Krishnarao Gavit
# 3  4               Navapur  Shirishkumar Surupsing Naik
# 4  5                 Sakri                Manjula Gavit
#
#                       Party    Vote                   Party.1  Unnamed: 6  \
# 0  Indian National Congress   82770                 Shiv Sena         NaN
# 1    Bharatiya Janata Party   94931  Indian National Congress         NaN
# 2    Bharatiya Janata Party  121605  Indian National Congress         NaN
# 3  Indian National Congress   74652               Independent         NaN
# 4               Independent   76166    Bharatiya Janata Party         NaN
#
#    Unnamed: 7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
mah=mah.reset_index()

# %%
mah['DIST_NAME']= mah['DIST_NAME'].apply(lambda x: str(x).lower())
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
mah.head()
# Out:
#       OBJECTID  ST_CODE      ST_NAME  DT_CODE    DIST_NAME  AC_NO  \
# 2645         1       27  MAHARASHTRA      1.0  nandurbar *      1
# 2646         1       27  MAHARASHTRA      1.0  nandurbar *      2
# 2647         7       27  MAHARASHTRA      7.0     amravati     41
# 2648         1       27  MAHARASHTRA      1.0  nandurbar *      3
# 2649         1       27  MAHARASHTRA      2.0        dhule      9
#
#              AC_NAME  PC_NO         PC_NAME  PC_ID STATUS  Shape_Leng  \
# 2645  Akkalkuwa (ST)      1  NANDURBAR (ST)   2701   None    2.894388
# 2646    Shahada (ST)      1  NANDURBAR (ST)   2701   None    2.618610
# 2647    Melghat (ST)      7   AMRAVATI (SC)   2707   None    3.711428
# 2648  Nandurbar (ST)      1  NANDURBAR (ST)   2701   None    2.580283
# 2649    Shirpur (ST)      1  NANDURBAR (ST)   2701   None    1.728193
#
#       Shape_Area                                           geometry
# 2645    0.194806  POLYGON ((74.43880 22.02530, 74.44376 22.02279...
# ...

# %%
results['Assembly Constituency'].nunique()
# Out:
# 288

# %%
results.tail()
# Out:
#        #     Assembly Constituency                  Candidate  \
# 283  284                   Shirala  Mansing Fattesingrao Naik
# 284  285            Palus-Kadegaon           Vishwajeet Kadam
# 285  286                  Khanapur             Anilbhau Babar
# 286  287  Tasgaon-Kavathe Mahankal                Suman Patil
# 287  288                       Jat   Vikram Balasaheb Sawantl
#
#                           Party    Vote                 Party.1  Unnamed: 6  \
# 283  Nationalist Congress Party  101933  Bharatiya Janata Party         NaN
# 284    Indian National Congress  171497       None of the Above         NaN
# 285                   Shiv Sena  116974             Independent         NaN
# 286  Nationalist Congress Party  128371               Shiv Sena         NaN
# 287    Indian National Congress   87184  Bharatiya Janata Party         NaN
#
#      Unnamed: 7
# 283         NaN
# 284         NaN
# 285         NaN
# 286         NaN
# 287         NaN

# %%
mah['DIST_NAME']= mah['DIST_NAME'].apply(lambda x: str(x).replace('*',''))

# %%
mah.head()
# Out:
#     DIST_NAME  OBJECTID  ST_CODE      ST_NAME  DT_CODE  AC_NO         AC_NAME  \
# 0  nandurbar          1       27  MAHARASHTRA      1.0      1  Akkalkuwa (ST)
# 1  nandurbar          1       27  MAHARASHTRA      1.0      2    Shahada (ST)
# 2    amravati         7       27  MAHARASHTRA      7.0     41    Melghat (ST)
# 3  nandurbar          1       27  MAHARASHTRA      1.0      3  Nandurbar (ST)
# 4       dhule         1       27  MAHARASHTRA      2.0      9    Shirpur (ST)
#
#    PC_NO         PC_NAME  PC_ID STATUS  Shape_Leng  Shape_Area  \
# 0      1  NANDURBAR (ST)   2701   None    2.894388    0.194806
# 1      1  NANDURBAR (ST)   2701   None    2.618610    0.094384
# 2      7   AMRAVATI (SC)   2707   None    3.711428    0.375752
# 3      1  NANDURBAR (ST)   2701   None    2.580283    0.109140
# 4      1  NANDURBAR (ST)   2701   None    1.728193    0.131644
#
#                                             geometry
# 0  POLYGON ((74.43880 22.02530, 74.44376 22.02279...
# ...

# %%
mah.tail()
# Out:
#       OBJECTID  ST_CODE      ST_NAME  DT_CODE   DIST_NAME  AC_NO      AC_NAME  \
# 2942        47       27  MAHARASHTRA     34.0    kolhapur    272  Radhanagari
# 2943        47       27  MAHARASHTRA     34.0    kolhapur    273        Kagal
# 2944        46       27  MAHARASHTRA     33.0  sindhudurg    269        Kudal
# 2945        47       27  MAHARASHTRA     34.0    kolhapur    271     Chandgad
# 2946        46       27  MAHARASHTRA     33.0  sindhudurg    270   Sawantwadi
#
#       PC_NO               PC_NAME  PC_ID STATUS  Shape_Leng  Shape_Area  \
# 2942     47              KOLHAPUR   2747   None    3.230545    0.151146
# 2943     47              KOLHAPUR   2747   None    2.411815    0.064359
# 2944     46  RATNAGIRI ?SINDHUDUR   2746   None    2.407060    0.122333
# 2945     47              KOLHAPUR   2747   None    2.750061    0.127986
# 2946     46  RATNAGIRI ?SINDHUDUR   2746   None    3.013116    0.138856
#
#                                                geometry
# ...

# %%
mah.shape
# Out:
# (302, 14)

# %%
mah['DIST_NAME'].nunique()
# Out:
# 35

# %%
results['Assembly Constituency'].nunique()
# Out:
# 288

# %%
results
# Out:
#        #     Assembly Constituency                    Candidate  \
# 0      1                 Akkalkuwa            Adv. K. C. Padavi
# 1      2                   Shahada         Rajesh Udesing Padvi
# 2      3                 Nandurbar  Vijaykumar Krishnarao Gavit
# 3      4                   Navapur  Shirishkumar Surupsing Naik
# 4      5                     Sakri                Manjula Gavit
# ..   ...                       ...                          ...
# 283  284                   Shirala    Mansing Fattesingrao Naik
# 284  285            Palus-Kadegaon             Vishwajeet Kadam
# 285  286                  Khanapur               Anilbhau Babar
# 286  287  Tasgaon-Kavathe Mahankal                  Suman Patil
# 287  288                       Jat     Vikram Balasaheb Sawantl
#
#                           Party    Vote                   Party.1  Unnamed: 6  \
# 0      Indian National Congress   82770                 Shiv Sena         NaN
# ...

# %%
'Akkalkuwa ' in mah['AC_NAME']
# Out:
# False

# %%
 mah['AC_NAME'].unique()
# Out:
# array(['Akkalkuwa', 'Shahada', 'Melghat', 'Nandurbar', 'Shirpur',
#        'Ramtek', 'Nawapur', 'Morshi', 'Savner', 'Gondiya', 'Tumsar',
#        'Sindkheda', 'Tirora', 'Katol', 'Chopda', 'Amgaon', 'Raver',
#        'Achalpur', 'Sakri', 'Arvi', 'Kamthi', 'Amalner', 'Jalgaon(Jamod)',
#        'Muktainagar', 'ArjuniMorgaon', 'Akot', 'Teosa', 'JalgaonRural',
#        'Daryapur', 'DhuleRural', 'Hingna', 'Bhandara', 'Sakoli',
#        'NagpurNorth', 'NagpurWest', 'Bhusawal', 'NagpurEast',
#        'NagpurCentral', 'NagpurSouthWest', 'JalgaonCity', 'NagpurSouth',
#        'Erandol', 'Malkapur', 'Umred', 'AkolaEast', 'DhuleCity', 'Wardha',
#        'Baglan', 'Badnera', 'Jamner', 'Amravati', 'MalegaonOuter',
#        'Balapur', 'DhamangaonRailway', 'Khamgaon', 'Pachora', 'Kalwan',
#        'Buldhana', 'Murtizapur', 'Deoli', 'Chalisgaon', 'Hinganghat',
#        'Armori', 'Nandgaon', 'AkolaWest', 'Karanja', 'Sillod', 'Chandvad',
# ...

# %%
mah['AC_NAME']= mah['AC_NAME'].apply(lambda x: str(x).replace('(SC)',''))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
mah['AC_NAME']= mah['AC_NAME'].apply(lambda x: str(x).replace('(ST)',''))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
mah['AC_NAME']= mah['AC_NAME'].apply(lambda x: str(x).replace(' ',''))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
 mah['AC_NAME'].nunique()
# Out:
# 289

# %%
 mah['PC_NO'].nunique()
# Out:
# 49

# %%
len( mah['AC_NAME'])
# Out:
# 302

# %%
merged = mah.set_index('AC_NAME').join(results.set_index('Assembly Constituency'))

# %%
merged.head()
# Out:
#             OBJECTID  ST_CODE      ST_NAME  DT_CODE   DIST_NAME  AC_NO  PC_NO  \
# Achalpur           7       27  MAHARASHTRA      7.0    amravati     42      7
# Aheri             12       27  MAHARASHTRA     12.0  gadchiroli     69     12
# Ahmadpur          41       27  MAHARASHTRA     28.0       latur    236     41
# Ahmednagar        37       27  MAHARASHTRA     26.0  ahmadnagar    225     37
# Airoli            25       27  MAHARASHTRA     21.0       thane    150     25
#
#                       PC_NAME  PC_ID STATUS  Shape_Leng  Shape_Area  \
# Achalpur        AMRAVATI (SC)   2707   None    1.838134    0.070445
# Aheri       GADCHIROLI-CHIMUR   2712   None    5.717477    0.661305
# Ahmadpur           LATUR (SC)   2741   None    1.922770    0.122978
# Ahmednagar         AHMEDNAGAR   2737   None    0.526649    0.009505
# Airoli                  THANE   2725   None    0.343307    0.002910
#
#                                                      geometry      #  \
# ...

# %%
fig, ax = plt.subplots(1, figsize=(10, 6))
ax.axis('off')
ax.set_title('State Wise Crime against women in India in 2015', fontdict={'fontsize': '25', 'fontweight' : '3'})
merged.plot(column='Vote', cmap='YlOrRd', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
merged.plot(column='Vote', cmap='YlOrRd', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)

# %%
merged['Party'].unique()
# Out:
# array(['Prahar Janshakti Party', 'Nationalist Congress Party', 'Unknown',
#        'Bharatiya Janata Party', 'Indian National Congress', 'Shiv Sena',
#        'Independent', 'Bahujan Vikas Aghadi',
#        'Communist Party of India (Marxist)', 'Rashtriya Samaj Paksha',
#        'Peasants And Workers Party of India', 'Swabhimani Paksha',
#        'Krantikari Shetkari Paksha', 'Jan Surajya Shakti'], dtype=object)

# %%
party= merged['Party'].to_list()

# %%
list(enumerate(party))
# Out:
# [(0, 'Prahar Janshakti Party'),
#  (1, 'Nationalist Congress Party'),
#  (2, 'Nationalist Congress Party'),
#  (3, nan),
#  (4, 'Bharatiya Janata Party'),
#  (5, 'Bharatiya Janata Party'),
#  (6, 'Indian National Congress'),
#  (7, nan),
#  (8, nan),
#  (9, 'Nationalist Congress Party'),
#  (10, 'Bharatiya Janata Party'),
#  (11, 'Shiv Sena'),
#  (12, 'Nationalist Congress Party'),
#  (13, 'Nationalist Congress Party'),
#  (14, 'Shiv Sena'),
#  (15, 'Indian National Congress'),
#  (16, 'Indian National Congress'),
#  (17, nan),
#  (18, nan),
#  (19, nan),
#  (20, nan),
#  (21, 'Bharatiya Janata Party'),
#  (22, 'Bharatiya Janata Party'),
#  (23, 'Bharatiya Janata Party'),
#  (24, 'Nationalist Congress Party'),
#  (25, nan),
#  (26, nan),
#  (27, nan),
#  (28, 'Bharatiya Janata Party'),
#  (29, 'Bharatiya Janata Party'),
#  (30, 'Independent'),
#  (31, 'Bharatiya Janata Party'),
#  (32, 'Shiv Sena'),
#  (33, 'Bharatiya Janata Party'),
#  (34, 'Nationalist Congress Party'),
# ...

# %%
import numpy as np

# %%
merged.replace(np.nan, 'Unknown', inplace=True)

# %%
from matplotlib.ticker import StrMethodFormatter

# %%
fig, ax = plt.subplots(1, figsize=(10, 6))
ax.axis('off')
ax.set_title('maharashtra state elections 2019', fontdict={'fontsize': '25', 'fontweight' : '3'})
merged.plot(column='Party', cmap='YlOrRd',  categorical=True,linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.15,0.5))
#ax.yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))
ax.set_axis_off()

plt.show()
